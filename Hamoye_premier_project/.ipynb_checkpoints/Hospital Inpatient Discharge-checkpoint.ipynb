# %% [markdown]
# # Predicting Length of Stay

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# |Features  |       Description    |
# |-|-|
# |**Hospital Service Area**    |     A description of the Health Service Area (HSA) in which the hospital is located. Blank for abortion records. Capital/Adirondack, Central NY, Finger Lakes, Hudson Valley, Long Island, New York City, Southern Tier, Western NY.|
# |**Hospital County**   |  A description of the county in which the hospital is located. Blank for abortion records.|
# |**Operating Certificate Number** | The facility Operating Certificate Number as assigned by NYS Department of Health. Blank for abortion records.|
# |**Permanent Facility Id** | Permanent Facility Identifier. Blank for abortion records.|
# |**Facility Name** |  The name of the facility where services were performed based on the Permanent Facility Identifier (PFI), as maintained by the NYSDOH Division of Health Facility Planning. For abortion records ‘Abortion Record – Facility Name Redacted’ appears.|
# |**Age Group** | Age in years at time of discharge. Grouped into the following age groups: 0 to 17, 18 to 29, 30 to 49, 50 to 69, and 70 or Older.|
# |**Zip Code - 3 digits** | The first three digits of the patient's zip code.|
# |**Gender** | Patient gender: (M) Male, (F) Female, (U) Unknown.|
# |**Race** | Patient race. Black/African American, Multi, Other Race, Unknown, White. Other Race includes Native Americans and Asian/Pacific Islander.|
# |**Ethnicity** | The ethnicity of the patient: Spanish/Hispanic Origin, Not of Spanish/Hispanic Origin, Multi, Unknown.|
# |**Length of Stay** | The total number of patient days at an acute level and/or other than acute care level (excluding leave of absence days) (Discharge Date - Admission Date) + 1.|
# |**Type of Admission** | A description of the manner in which the patient was admitted to the health care facility: Elective, Emergency, Newborn, Not Available, Trauma, Urgent.|
# |**Patient Disposition** | The patient's destination or status upon discharge.|
# |**Discharge Year**    |     The year (CCYY) of discharge.|
# |**CCS Diagnosis Code** | AHRQ Clinical Classification Software (CCS) Diagnosis Category Description.|
# |**CCS Diagnosis Description** | AHRQ Clinical Classification Software (CCS) Diagnosis Category Description.|
# |**CCS Procedure Code** |  AHRQ Clinical Classification Software (CCS) ICD-9 Procedure Category Code.|
# |**CCS Procedure Description** | AHRQ Clinical Classification Software (CCS) ICD-9 Procedure Category Description.|
# |**APR DRG Code** | APR-DRG Classification Code.|
# |**APR DRG Description** | APR-DRG Classification Code Description in Calendar Year 2017, Version 34 of the APR- DRG Grouper.|
# |**APR Severity of Illness Code** | APR-DRG Severity of Illness Code: 1, 2, 3, 4.|
# |**APR Severity of Illness Description** | All Patient Refined Severity of Illness (APR SOI) Description: Minor (1), Moderate (2), Major (3), Extreme (4)|
# |**APR Risk of Mortality** | All Patient Refined Risk of Mortality (APR ROM) Description: Minor (1), Moderate (2), Major (3), Extreme (4).|
# |**APR Medical Surgical Description** | APR-DRG specific classification of Medical, Surgical or Not Applicable.|
# |**Payment Typology 1** | A description of the type of payment for this occurrence.|
# |**Payment Typology 2** | A description of the type of payment for this occurrence.|
# |**Payment Typology 3** | A description of the type of payment for this occurrence.|
# |**Birth Weight** |  The neonate birth weight in grams; rounded to nearest 100g.|
# |**Abortion Edit Indicator** | A flag to indicate if the discharge record contains any indication of abortion ("N" = No; "Y" = Yes)|
# |**Emergency Department Indicator** | Emergency Department Indicator is set based on the submitted revenue codes. If the record contained an Emergency Department revenue code of 045X, the indicator is set to "Y", otherwise it will be “N”.|
# |**Total Charges** | Total charges for the discharge.|
# |**Total Costs** | Total estimated cost for the discharge.|

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Setting color palatte
colors = ['#007bff','#fcb107','#28a745','#dc3545']
sns.set_theme('talk')
sns.set_palette(colors)

plt.rcParams['figure.dpi'] = 70
plt.rcParams['figure.figsize'] = [15, 9]

# %%
df = pd.read_csv("C:/Users/HP/Documents/workspace/Ml-opzoomcamp/Hamoye/Hamoye_project/Hospital_Inpatient_Discharges__SPARCS_De-Identified___2017.csv")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         Hospital Service Area Hospital County  Operating Certificate Number  \
# 0               Hudson Valley     Westchester                     5903001.0
# 1               Hudson Valley     Westchester                     5903001.0
# 2               Hudson Valley     Westchester                     5903001.0
# 3               Hudson Valley     Westchester                     5903001.0
# 4               Hudson Valley     Westchester                     5903001.0
# ...                       ...             ...                           ...
# 2343564         Hudson Valley        Rockland                     4329000.0
# 2343565         Hudson Valley        Rockland                     4329000.0
# 2343566         Hudson Valley        Rockland                     4329000.0
# 2343567         New York City           Bronx                     7000006.0
# 2343568          Finger Lakes         Steuben                     5002001.0
#
#          Permanent Facility Id  \
# 0                       1061.0
# 1                       1061.0
# 2                       1061.0
# 3                       1061.0
# 4                       1061.0
# ...                        ...
# 2343564                  779.0
# 2343565                  779.0
# 2343566                  779.0
# 2343567                 3058.0
# 2343568                  870.0
#
#                                              Facility Name    Age Group  \
# 0                         Montefiore Mount Vernon Hospital     30 to 49
# 1                         Montefiore Mount Vernon Hospital     50 to 69
# 2                         Montefiore Mount Vernon Hospital     30 to 49
# 3                         Montefiore Mount Vernon Hospital     50 to 69
# 4                         Montefiore Mount Vernon Hospital     18 to 29
# ...                                                    ...          ...
# 2343564                 Good Samaritan Hospital of Suffern     50 to 69
# 2343565                 Good Samaritan Hospital of Suffern     50 to 69
# 2343566                 Good Samaritan Hospital of Suffern     30 to 49
# 2343567  Montefiore Med Center - Jack D Weiler Hosp of ...  70 or Older
# 2343568                            St James Mercy Hospital     18 to 29
#
#         Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 0                       NaN      M                   White  Not Span/Hispanic
# 1                       105      M                   White   Spanish/Hispanic
# 2                       105      F                   White            Unknown
# 3                       105      F                   White  Not Span/Hispanic
# 4                       105      F                   White   Spanish/Hispanic
# ...                     ...    ...                     ...                ...
# 2343564                 109      F                   White  Not Span/Hispanic
# 2343565                 109      F              Other Race   Spanish/Hispanic
# 2343566                 NaN      M              Other Race  Not Span/Hispanic
# 2343567                 104      F  Black/African American            Unknown
# 2343568                 148      F                   White  Not Span/Hispanic
#
#          ... APR Risk of Mortality APR Medical Surgical Description  \
# 0        ...                 Minor                          Medical
# 1        ...              Moderate                          Medical
# 2        ...              Moderate                          Medical
# 3        ...              Moderate                          Medical
# 4        ...                 Minor                          Medical
# ...      ...                   ...                              ...
# 2343564  ...              Moderate                         Surgical
# 2343565  ...              Moderate                          Medical
# 2343566  ...                 Minor                          Medical
# 2343567  ...                 Minor                         Surgical
# 2343568  ...                 Minor                          Medical
#
#                 Payment Typology 1  Payment Typology 2  Payment Typology 3  \
# 0                         Medicare            Medicare            Self-Pay
# 1                         Medicaid            Medicaid            Self-Pay
# 2        Department of Corrections            Self-Pay                 NaN
# 3                         Medicaid            Medicaid            Self-Pay
# 4        Department of Corrections            Self-Pay                 NaN
# ...                            ...                 ...                 ...
# 2343564   Private Health Insurance            Medicare                 NaN
# 2343565                   Medicaid                 NaN                 NaN
# 2343566        Miscellaneous/Other            Medicaid                 NaN
# 2343567                   Medicare                 NaN                 NaN
# 2343568                   Medicaid                 NaN                 NaN
#
#         Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0                NaN                        N                              N
# 1                NaN                        N                              N
# 2                NaN                        N                              N
# 3                NaN                        N                              N
# 4                NaN                        N                              N
# ...              ...                      ...                            ...
# 2343564          NaN                        N                              N
# 2343565          NaN                        N                              Y
# 2343566          NaN                        N                              Y
# 2343567          NaN                        N                              N
# 2343568          NaN                        N                              Y
#
#          Total Charges Total Costs
# 0            114168.00    40464.04
# 1             58517.00    26046.50
# 2             39647.04    17397.59
# 3             36031.09    16118.84
# 4             30534.00    11921.05
# ...                ...         ...
# 2343564       87545.08    16781.23
# 2343565       31896.05     6003.38
# 2343566       49292.49     8863.14
# 2343567       66399.81    13068.87
# 2343568        2933.75     1225.95
#
# [2343569 rows x 34 columns]

# %%
df.shape
# Out:
# (2343569, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2343569 entries, 0 to 2343568
# Data columns (total 34 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   Hospital Service Area                object
#  1   Hospital County                      object
#  2   Operating Certificate Number         float64
#  3   Permanent Facility Id                float64
#  4   Facility Name                        object
#  5   Age Group                            object
#  6   Zip Code - 3 digits                  object
#  7   Gender                               object
#  8   Race                                 object
#  9   Ethnicity                            object
#  10  Length of Stay                       object
#  11  Type of Admission                    object
#  12  Patient Disposition                  object
#  13  Discharge Year                       int64
#  14  CCS Diagnosis Code                   int64
#  15  CCS Diagnosis Description            object
#  16  CCS Procedure Code                   int64
#  17  CCS Procedure Description            object
#  18  APR DRG Code                         int64
#  19  APR DRG Description                  object
#  20  APR MDC Code                         int64
#  21  APR MDC Description                  object
#  22  APR Severity of Illness Code         int64
#  23  APR Severity of Illness Description  object
#  24  APR Risk of Mortality                object
#  25  APR Medical Surgical Description     object
#  26  Payment Typology 1                   object
#  27  Payment Typology 2                   object
#  28  Payment Typology 3                   object
#  29  Birth Weight                         object
#  30  Abortion Edit Indicator              object
#  31  Emergency Department Indicator       object
#  32  Total Charges                        float64
#  33  Total Costs                          float64
# dtypes: float64(4), int64(6), object(24)
# memory usage: 607.9+ MB

# %%
df.columns
# Out:
# Index(['Hospital Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Permanent Facility Id',
#        'Facility Name', 'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race',
#        'Ethnicity', 'Length of Stay', 'Type of Admission',
#        'Patient Disposition', 'Discharge Year', 'CCS Diagnosis Code',
#        'CCS Diagnosis Description', 'CCS Procedure Code',
#        'CCS Procedure Description', 'APR DRG Code', 'APR DRG Description',
#        'APR MDC Code', 'APR MDC Description', 'APR Severity of Illness Code',
#        'APR Severity of Illness Description', 'APR Risk of Mortality',
#        'APR Medical Surgical Description', 'Payment Typology 1',
#        'Payment Typology 2', 'Payment Typology 3', 'Birth Weight',
#        'Abortion Edit Indicator', 'Emergency Department Indicator',
#        'Total Charges', 'Total Costs'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.describe().round(3)
# Out:
#        operating_certificate_number  permanent_facility_id  discharge_year  \
# count                   2338414.000            2338414.000       2343569.0
# mean                    4985785.847               1038.981          2017.0
# std                     2263243.602                720.228             0.0
# min                      101000.000                  1.000          2017.0
# 25%                     2951001.000                541.000          2017.0
# 50%                     5904001.000               1097.000          2017.0
# 75%                     7002017.000               1453.000          2017.0
# max                     7004010.000               9431.000          2017.0
#
#        ccs_diagnosis_code  ccs_procedure_code  apr_drg_code  apr_mdc_code  \
# count         2343569.000         2343569.000   2343569.000   2343569.000
# mean              189.873             101.400       416.180        10.311
# std               164.945              86.816       242.494         5.900
# min                 1.000               0.000         1.000         0.000
# 25%               101.000               0.000       198.000         5.000
# 50%               157.000              98.000       383.000         9.000
# 75%               218.000             180.000       640.000        15.000
# max              2617.000             231.000       956.000        25.000
#
#        apr_severity_of_illness_code  total_charges  total_costs
# count                   2343569.000    2343569.000   2343569.00
# mean                          2.021      49723.805     16647.35
# std                           0.889      95241.291     43773.89
# min                           0.000          0.010         0.00
# 25%                           1.000      13539.800      4784.65
# 50%                           2.000      26574.960      8924.51
# 75%                           3.000      53106.690     17280.76
# max                           4.000    9696644.890   8868612.79

# %%
df.isnull().sum()
# Out:
# hospital_service_area                     5155
# hospital_county                           5155
# operating_certificate_number              5155
# permanent_facility_id                     5155
# facility_name                                0
# age_group                                    0
# zip_code_-_3_digits                      39019
# gender                                       0
# race                                         0
# ethnicity                                    0
# length_of_stay                               0
# type_of_admission                            0
# patient_disposition                          0
# discharge_year                               0
# ccs_diagnosis_code                           0
# ccs_diagnosis_description                    0
# ccs_procedure_code                           0
# ccs_procedure_description                    0
# apr_drg_code                                 0
# apr_drg_description                          0
# apr_mdc_code                                 0
# apr_mdc_description                          0
# apr_severity_of_illness_code                 0
# apr_severity_of_illness_description        240
# apr_risk_of_mortality                      240
# apr_medical_surgical_description             0
# payment_typology_1                           0
# payment_typology_2                      878722
# payment_typology_3                     1737244
# birth_weight                           2115685
# abortion_edit_indicator                      0
# emergency_department_indicator               0
# total_charges                                0
# total_costs                                  0
# dtype: int64

# %%
df['zip_code_-_3_digits'].value_counts()
# Out:
# 112    293867
# 104    217951
# 117    188469
# 100    160860
# 113    119787
# 114     91975
# 115     89023
# 142     66942
# OOS     66761
# 105     62234
# 103     62013
# 146     59046
# 109     58871
# 125     46514
# 140     44203
# 130     39712
# 120     36129
# 119     34140
# 145     33309
# 121     30954
# 144     29934
# 107     29683
# 132     27858
# 136     26455
# 110     26278
# 128     24312
# 148     24153
# 141     21662
# 134     20837
# 124     20111
# 122     19476
# 111     18920
# 123     18868
# 131     18116
# 147     17487
# 116     17082
# 133     15619
# 129     14007
# 138     12170
# 127     11774
# 137     11614
# 126     10670
# 135     10189
# 143     10055
# 106      8895
# 108      8622
# 118      8130
# 139      7130
# 149      6162
# 101      5521
# Name: zip_code_-_3_digits, dtype: int64

# %%
df = df.drop(['payment_typology_2', 'payment_typology_3', 'birth_weight'], axis= 1)

# %%
df.isnull().sum()
# Out:
# hospital_service_area                   5155
# hospital_county                         5155
# operating_certificate_number            5155
# permanent_facility_id                   5155
# facility_name                              0
# age_group                                  0
# zip_code_-_3_digits                    39019
# gender                                     0
# race                                       0
# ethnicity                                  0
# length_of_stay                             0
# type_of_admission                          0
# patient_disposition                        0
# discharge_year                             0
# ccs_diagnosis_code                         0
# ccs_diagnosis_description                  0
# ccs_procedure_code                         0
# ccs_procedure_description                  0
# apr_drg_code                               0
# apr_drg_description                        0
# apr_mdc_code                               0
# apr_mdc_description                        0
# apr_severity_of_illness_code               0
# apr_severity_of_illness_description      240
# apr_risk_of_mortality                    240
# apr_medical_surgical_description           0
# payment_typology_1                         0
# abortion_edit_indicator                    0
# emergency_department_indicator             0
# total_charges                              0
# total_costs                                0
# dtype: int64

# %%
df = df.dropna(subset=['hospital_service_area', 'hospital_county', 'operating_certificate_number',
           'permanent_facility_id', 'zip_code_-_3_digits', 
           'apr_severity_of_illness_description', 'apr_risk_of_mortality'])

# %%
df.isnull().sum()
# Out:
# hospital_service_area                  0
# hospital_county                        0
# operating_certificate_number           0
# permanent_facility_id                  0
# facility_name                          0
# age_group                              0
# zip_code_-_3_digits                    0
# gender                                 0
# race                                   0
# ethnicity                              0
# length_of_stay                         0
# type_of_admission                      0
# patient_disposition                    0
# discharge_year                         0
# ccs_diagnosis_code                     0
# ccs_diagnosis_description              0
# ccs_procedure_code                     0
# ccs_procedure_description              0
# apr_drg_code                           0
# apr_drg_description                    0
# apr_mdc_code                           0
# apr_mdc_description                    0
# apr_severity_of_illness_code           0
# apr_severity_of_illness_description    0
# apr_risk_of_mortality                  0
# apr_medical_surgical_description       0
# payment_typology_1                     0
# abortion_edit_indicator                0
# emergency_department_indicator         0
# total_charges                          0
# total_costs                            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2304316 entries, 1 to 2343568
# Data columns (total 31 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   hospital_service_area                object
#  1   hospital_county                      object
#  2   operating_certificate_number         float64
#  3   permanent_facility_id                float64
#  4   facility_name                        object
#  5   age_group                            object
#  6   zip_code_-_3_digits                  object
#  7   gender                               object
#  8   race                                 object
#  9   ethnicity                            object
#  10  length_of_stay                       object
#  11  type_of_admission                    object
#  12  patient_disposition                  object
#  13  discharge_year                       int64
#  14  ccs_diagnosis_code                   int64
#  15  ccs_diagnosis_description            object
#  16  ccs_procedure_code                   int64
#  17  ccs_procedure_description            object
#  18  apr_drg_code                         int64
#  19  apr_drg_description                  object
#  20  apr_mdc_code                         int64
#  21  apr_mdc_description                  object
#  22  apr_severity_of_illness_code         int64
#  23  apr_severity_of_illness_description  object
#  24  apr_risk_of_mortality                object
#  25  apr_medical_surgical_description     object
#  26  payment_typology_1                   object
#  27  abortion_edit_indicator              object
#  28  emergency_department_indicator       object
#  29  total_charges                        float64
#  30  total_costs                          float64
# dtypes: float64(4), int64(6), object(21)
# memory usage: 562.6+ MB

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# hospital_service_area
# ['Hudson Valley' 'New York City' 'Western NY' 'Central NY'
#  'Capital/Adirond']
# 8
#
# hospital_county
# ['Westchester' 'Manhattan' 'Sullivan' 'Erie' 'Kings']
# 57
#
# operating_certificate_number
# [5903001. 5904001. 7002002. 5263000. 1401005.]
# 174
#
# permanent_facility_id
# [1061. 1072. 1439.  971.  210.]
# 210
#
# facility_name
# ['Montefiore Mount Vernon Hospital' 'Montefiore New Rochelle Hospital'
#  'Mount Sinai Beth Israel' 'Catskill Regional Medical Center'
#  'Erie County Medical Center']
# 209
#
# age_group
# ['50 to 69' '30 to 49' '18 to 29' '70 or Older' '0 to 17']
# 5
#
# zip_code_-_3_digits
# ['105' '107' '104' '108' '100']
# 50
#
# gender
# ['M' 'F' 'U']
# 3
#
# race
# ['White' 'Black/African American' 'Other Race' 'Multi-racial']
# 4
#
# ethnicity
# ['Spanish/Hispanic' 'Unknown' 'Not Span/Hispanic' 'Multi-ethnic']
# 4
#
# length_of_stay
# ['8' '6' '4' '3' '1']
# 120
#
# type_of_admission
# ['Emergency' 'Elective' 'Newborn' 'Urgent' 'Trauma']
# 6
#
# patient_disposition
# ['Skilled Nursing Home' 'Court/Law Enforcement' 'Short-term Hospital'
#  'Home or Self Care' 'Expired']
# 20
#
# discharge_year
# [2017]
# 1
#
# ccs_diagnosis_code
# [ 99 161 238   2 660]
# 259
#
# ccs_diagnosis_description
# ['Hypertension with complications and secondary hypertension'
#  'Other diseases of kidney and ureters'
#  'Complications of surgical procedures or medical care'
#  'Septicemia (except in labor)' 'Alcohol-related disorders']
# 259
#
# ccs_procedure_code
# [108 102 222   0 231]
# 222
#
# ccs_procedure_description
# ['INDWELLING CATHETER' 'URETERAL CATHETERIZATN' 'BLOOD TRANSFUSION'
#  'NO PROC' 'OTHER THERAPEUTIC PRCS']
# 222
#
# apr_drg_code
# [194 465 721 720 280]
# 312
#
# apr_drg_description
# ['Heart failure'
#  'Urinary stones & acquired upper urinary tract obstruction'
#  'Post-operative, post-traumatic, other device infections'
#  'Septicemia & disseminated infections' 'Alcoholic liver disease']
# 312
#
# apr_mdc_code
# [ 5 11 18  7 10]
# 24
#
# apr_mdc_description
# ['Diseases and Disorders of the Circulatory System'
#  'Diseases and Disorders of the Kidney and Urinary Tract'
#  'Infectious and Parasitic Diseases, Systemic or Unspecified Sites'
#  'Diseases and Disorders of the Hepatobiliary System and Pancreas'
#  'Endocrine, Nutritional and Metabolic Diseases and Disorders']
# 24
#
# apr_severity_of_illness_code
# [3 2 1 4]
# 4
#
# apr_severity_of_illness_description
# ['Major' 'Moderate' 'Minor' 'Extreme']
# 4
#
# apr_risk_of_mortality
# ['Moderate' 'Minor' 'Major' 'Extreme']
# 4
#
# apr_medical_surgical_description
# ['Medical' 'Surgical']
# 2
#
# payment_typology_1
# ['Medicaid' 'Department of Corrections' 'Medicare'
#  'Private Health Insurance' 'Blue Cross/Blue Shield']
# 10
#
# abortion_edit_indicator
# ['N']
# 1
#
# emergency_department_indicator
# ['N' 'Y']
# 2
#
# total_charges
# [58517.   39647.04 36031.09 30534.   49290.08]
# 1819890
#
# total_costs
# [26046.5  17397.59 16118.84 11921.05 18503.26]
# 1519753

# %%
df['length_of_stay'] = df['length_of_stay'].apply(lambda x: str(x).split(' ')[0])
df['length_of_stay'] = pd.to_numeric(df['length_of_stay'])

# %%
df
# Out:
#         hospital_service_area hospital_county  operating_certificate_number  \
# 1               Hudson Valley     Westchester                     5903001.0
# 2               Hudson Valley     Westchester                     5903001.0
# 3               Hudson Valley     Westchester                     5903001.0
# 4               Hudson Valley     Westchester                     5903001.0
# 5               Hudson Valley     Westchester                     5903001.0
# ...                       ...             ...                           ...
# 2343563         New York City       Manhattan                     7002012.0
# 2343564         Hudson Valley        Rockland                     4329000.0
# 2343565         Hudson Valley        Rockland                     4329000.0
# 2343567         New York City           Bronx                     7000006.0
# 2343568          Finger Lakes         Steuben                     5002001.0
#
#          permanent_facility_id  \
# 1                       1061.0
# 2                       1061.0
# 3                       1061.0
# 4                       1061.0
# 5                       1061.0
# ...                        ...
# 2343563                 1447.0
# 2343564                  779.0
# 2343565                  779.0
# 2343567                 3058.0
# 2343568                  870.0
#
#                                              facility_name    age_group  \
# 1                         Montefiore Mount Vernon Hospital     50 to 69
# 2                         Montefiore Mount Vernon Hospital     30 to 49
# 3                         Montefiore Mount Vernon Hospital     50 to 69
# 4                         Montefiore Mount Vernon Hospital     18 to 29
# 5                         Montefiore Mount Vernon Hospital     50 to 69
# ...                                                    ...          ...
# 2343563                       Hospital for Special Surgery     50 to 69
# 2343564                 Good Samaritan Hospital of Suffern     50 to 69
# 2343565                 Good Samaritan Hospital of Suffern     50 to 69
# 2343567  Montefiore Med Center - Jack D Weiler Hosp of ...  70 or Older
# 2343568                            St James Mercy Hospital     18 to 29
#
#         zip_code_-_3_digits gender                    race          ethnicity  \
# 1                       105      M                   White   Spanish/Hispanic
# 2                       105      F                   White            Unknown
# 3                       105      F                   White  Not Span/Hispanic
# 4                       105      F                   White   Spanish/Hispanic
# 5                       105      M  Black/African American  Not Span/Hispanic
# ...                     ...    ...                     ...                ...
# 2343563                 117      M                   White  Not Span/Hispanic
# 2343564                 109      F                   White  Not Span/Hispanic
# 2343565                 109      F              Other Race   Spanish/Hispanic
# 2343567                 104      F  Black/African American            Unknown
# 2343568                 148      F                   White  Not Span/Hispanic
#
#          ...                                apr_mdc_description  \
# 1        ...   Diseases and Disorders of the Circulatory System
# 2        ...  Diseases and Disorders of the Kidney and Urina...
# 3        ...  Infectious and Parasitic Diseases, Systemic or...
# 4        ...  Infectious and Parasitic Diseases, Systemic or...
# 5        ...  Diseases and Disorders of the Hepatobiliary Sy...
# ...      ...                                                ...
# 2343563  ...  Diseases and Disorders of the Musculoskeletal ...
# 2343564  ...   Diseases and Disorders of the Respiratory System
# 2343565  ...   Diseases and Disorders of the Circulatory System
# 2343567  ...  Diseases and Disorders of the Female Reproduct...
# 2343568  ...  Alcohol/Drug Use and Alcohol/Drug Induced Orga...
#
#         apr_severity_of_illness_code apr_severity_of_illness_description  \
# 1                                  3                               Major
# 2                                  2                            Moderate
# 3                                  2                            Moderate
# 4                                  2                            Moderate
# 5                                  3                               Major
# ...                              ...                                 ...
# 2343563                            2                            Moderate
# 2343564                            1                               Minor
# 2343565                            2                            Moderate
# 2343567                            2                            Moderate
# 2343568                            2                            Moderate
#
#          apr_risk_of_mortality  apr_medical_surgical_description  \
# 1                     Moderate                           Medical
# 2                     Moderate                           Medical
# 3                     Moderate                           Medical
# 4                        Minor                           Medical
# 5                        Major                           Medical
# ...                        ...                               ...
# 2343563                  Minor                          Surgical
# 2343564               Moderate                          Surgical
# 2343565               Moderate                           Medical
# 2343567                  Minor                          Surgical
# 2343568                  Minor                           Medical
#
#                 payment_typology_1  abortion_edit_indicator  \
# 1                         Medicaid                        N
# 2        Department of Corrections                        N
# 3                         Medicaid                        N
# 4        Department of Corrections                        N
# 5                         Medicare                        N
# ...                            ...                      ...
# 2343563   Private Health Insurance                        N
# 2343564   Private Health Insurance                        N
# 2343565                   Medicaid                        N
# 2343567                   Medicare                        N
# 2343568                   Medicaid                        N
#
#         emergency_department_indicator  total_charges total_costs
# 1                                    N       58517.00    26046.50
# 2                                    N       39647.04    17397.59
# 3                                    N       36031.09    16118.84
# 4                                    N       30534.00    11921.05
# 5                                    N       49290.08    18503.26
# ...                                ...            ...         ...
# 2343563                              N       93547.00    33621.00
# 2343564                              N       87545.08    16781.23
# 2343565                              Y       31896.05     6003.38
# 2343567                              N       66399.81    13068.87
# 2343568                              Y        2933.75     1225.95
#
# [2304316 rows x 31 columns]

# %%
df['zip_code_-_3_digits'].unique()
# Out:
# array(['105', '107', '104', '108', '100', '127', '109', '125', '124',
#        'OOS', '147', '112', '116', '113', '114', '101', '117', '119',
#        '103', '111', '110', '134', '139', '132', '130', '131', '136',
#        '123', '122', '133', '120', '146', '138', '121', '128', '106',
#        '115', '118', '145', '148', '144', '126', '137', '142', '140',
#        '143', '129', '135', '149', '141'], dtype=object)

# %%
df['zip_code_-_3_digits'].value_counts()
# Out:
# 112    293826
# 104    217920
# 117    188443
# 100    160851
# 113    119770
# 114     91954
# 115     89019
# 142     66934
# OOS     66753
# 105     62229
# 103     62011
# 146     59044
# 109     58867
# 125     46508
# 140     44203
# 130     39707
# 120     36128
# 119     34127
# 145     33309
# 121     30952
# 144     29933
# 107     29682
# 132     27857
# 136     26451
# 110     26278
# 128     24311
# 148     24150
# 141     21660
# 134     20836
# 124     20110
# 122     19476
# 111     18918
# 123     18866
# 131     18116
# 147     17486
# 116     17078
# 133     15617
# 129     14007
# 138     12170
# 127     11774
# 137     11613
# 126     10670
# 135     10189
# 143     10055
# 106      8895
# 108      8622
# 118      8130
# 139      7129
# 149      6162
# 101      5520
# Name: zip_code_-_3_digits, dtype: int64

# %%
df['zip_code_-_3_digits'] = df['zip_code_-_3_digits'].apply(lambda x: str(x).replace('OOS','999'))  
df['zip_code_-_3_digits'] = pd.to_numeric(df['zip_code_-_3_digits'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2304316 entries, 1 to 2343568
# Data columns (total 31 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   hospital_service_area                object
#  1   hospital_county                      object
#  2   operating_certificate_number         float64
#  3   permanent_facility_id                float64
#  4   facility_name                        object
#  5   age_group                            object
#  6   zip_code_-_3_digits                  int64
#  7   gender                               object
#  8   race                                 object
#  9   ethnicity                            object
#  10  length_of_stay                       int64
#  11  type_of_admission                    object
#  12  patient_disposition                  object
#  13  discharge_year                       int64
#  14  ccs_diagnosis_code                   int64
#  15  ccs_diagnosis_description            object
#  16  ccs_procedure_code                   int64
#  17  ccs_procedure_description            object
#  18  apr_drg_code                         int64
#  19  apr_drg_description                  object
#  20  apr_mdc_code                         int64
#  21  apr_mdc_description                  object
#  22  apr_severity_of_illness_code         int64
#  23  apr_severity_of_illness_description  object
#  24  apr_risk_of_mortality                object
#  25  apr_medical_surgical_description     object
#  26  payment_typology_1                   object
#  27  abortion_edit_indicator              object
#  28  emergency_department_indicator       object
#  29  total_charges                        float64
#  30  total_costs                          float64
# dtypes: float64(4), int64(8), object(19)
# memory usage: 562.6+ MB

# %%
df
# Out:
#         hospital_service_area hospital_county  operating_certificate_number  \
# 1               Hudson Valley     Westchester                     5903001.0
# 2               Hudson Valley     Westchester                     5903001.0
# 3               Hudson Valley     Westchester                     5903001.0
# 4               Hudson Valley     Westchester                     5903001.0
# 5               Hudson Valley     Westchester                     5903001.0
# ...                       ...             ...                           ...
# 2343563         New York City       Manhattan                     7002012.0
# 2343564         Hudson Valley        Rockland                     4329000.0
# 2343565         Hudson Valley        Rockland                     4329000.0
# 2343567         New York City           Bronx                     7000006.0
# 2343568          Finger Lakes         Steuben                     5002001.0
#
#          permanent_facility_id  \
# 1                       1061.0
# 2                       1061.0
# 3                       1061.0
# 4                       1061.0
# 5                       1061.0
# ...                        ...
# 2343563                 1447.0
# 2343564                  779.0
# 2343565                  779.0
# 2343567                 3058.0
# 2343568                  870.0
#
#                                              facility_name    age_group  \
# 1                         Montefiore Mount Vernon Hospital     50 to 69
# 2                         Montefiore Mount Vernon Hospital     30 to 49
# 3                         Montefiore Mount Vernon Hospital     50 to 69
# 4                         Montefiore Mount Vernon Hospital     18 to 29
# 5                         Montefiore Mount Vernon Hospital     50 to 69
# ...                                                    ...          ...
# 2343563                       Hospital for Special Surgery     50 to 69
# 2343564                 Good Samaritan Hospital of Suffern     50 to 69
# 2343565                 Good Samaritan Hospital of Suffern     50 to 69
# 2343567  Montefiore Med Center - Jack D Weiler Hosp of ...  70 or Older
# 2343568                            St James Mercy Hospital     18 to 29
#
#          zip_code_-_3_digits gender                    race  \
# 1                        105      M                   White
# 2                        105      F                   White
# 3                        105      F                   White
# 4                        105      F                   White
# 5                        105      M  Black/African American
# ...                      ...    ...                     ...
# 2343563                  117      M                   White
# 2343564                  109      F                   White
# 2343565                  109      F              Other Race
# 2343567                  104      F  Black/African American
# 2343568                  148      F                   White
#
#                  ethnicity  ...  \
# 1         Spanish/Hispanic  ...
# 2                  Unknown  ...
# 3        Not Span/Hispanic  ...
# 4         Spanish/Hispanic  ...
# 5        Not Span/Hispanic  ...
# ...                    ...  ...
# 2343563  Not Span/Hispanic  ...
# 2343564  Not Span/Hispanic  ...
# 2343565   Spanish/Hispanic  ...
# 2343567            Unknown  ...
# 2343568  Not Span/Hispanic  ...
#
#                                        apr_mdc_description  \
# 1         Diseases and Disorders of the Circulatory System
# 2        Diseases and Disorders of the Kidney and Urina...
# 3        Infectious and Parasitic Diseases, Systemic or...
# 4        Infectious and Parasitic Diseases, Systemic or...
# 5        Diseases and Disorders of the Hepatobiliary Sy...
# ...                                                    ...
# 2343563  Diseases and Disorders of the Musculoskeletal ...
# 2343564   Diseases and Disorders of the Respiratory System
# 2343565   Diseases and Disorders of the Circulatory System
# 2343567  Diseases and Disorders of the Female Reproduct...
# 2343568  Alcohol/Drug Use and Alcohol/Drug Induced Orga...
#
#         apr_severity_of_illness_code apr_severity_of_illness_description  \
# 1                                  3                               Major
# 2                                  2                            Moderate
# 3                                  2                            Moderate
# 4                                  2                            Moderate
# 5                                  3                               Major
# ...                              ...                                 ...
# 2343563                            2                            Moderate
# 2343564                            1                               Minor
# 2343565                            2                            Moderate
# 2343567                            2                            Moderate
# 2343568                            2                            Moderate
#
#          apr_risk_of_mortality  apr_medical_surgical_description  \
# 1                     Moderate                           Medical
# 2                     Moderate                           Medical
# 3                     Moderate                           Medical
# 4                        Minor                           Medical
# 5                        Major                           Medical
# ...                        ...                               ...
# 2343563                  Minor                          Surgical
# 2343564               Moderate                          Surgical
# 2343565               Moderate                           Medical
# 2343567                  Minor                          Surgical
# 2343568                  Minor                           Medical
#
#                 payment_typology_1  abortion_edit_indicator  \
# 1                         Medicaid                        N
# 2        Department of Corrections                        N
# 3                         Medicaid                        N
# 4        Department of Corrections                        N
# 5                         Medicare                        N
# ...                            ...                      ...
# 2343563   Private Health Insurance                        N
# 2343564   Private Health Insurance                        N
# 2343565                   Medicaid                        N
# 2343567                   Medicare                        N
# 2343568                   Medicaid                        N
#
#         emergency_department_indicator  total_charges total_costs
# 1                                    N       58517.00    26046.50
# 2                                    N       39647.04    17397.59
# 3                                    N       36031.09    16118.84
# 4                                    N       30534.00    11921.05
# 5                                    N       49290.08    18503.26
# ...                                ...            ...         ...
# 2343563                              N       93547.00    33621.00
# 2343564                              N       87545.08    16781.23
# 2343565                              Y       31896.05     6003.38
# 2343567                              N       66399.81    13068.87
# 2343568                              Y        2933.75     1225.95
#
# [2304316 rows x 31 columns]

# %%
sns.diverging_palette(250, 0,

# %% [markdown]
# # Exploratory Data Analysis

# %%
f, ax = plt.subplots(figsize=(11, 9))
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(250, 0, n=100),
    square=True)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=60,
    horizontalalignment='right'
);

# %%
df[['age_group','length_of_stay']].groupby('age_group', as_index=False).mean()
# Out:
#      age_group  length_of_stay
# 0      0 to 17        4.036644
# 1     18 to 29        4.520078
# 2     30 to 49        4.807785
# 3     50 to 69        5.931375
# 4  70 or Older        6.149861

# %%
#f, ax = plt.subplots(figsize=(25, 15))
sns.countplot(x='apr_severity_of_illness_description', data = df)
plt.xticks(rotation=90)
plt.title('Procedure Descriptions for Newborns Who Stay 120 Days or Longer')
plt.show()

# %%
sns.boxplot(x="apr_severity_of_illness_description", y="length_of_stay", data=df)
# Out:
# <AxesSubplot:xlabel='apr_severity_of_illness_description', ylabel='length_of_stay'>

# %%
f, ax = plt.subplots(figsize=(15, 9))
sns.boxplot(x="apr_severity_of_illness_description", y="length_of_stay", data=df)

ax.set(ylim=(0, 30))
plt.title('Length of Stay vs. apr_severity_of_illness')
plt.show()

# %%
#f, ax = plt.subplots(figsize=(25, 15))
sns.countplot(x='ccs_diagnosis_description', data = df)
plt.xticks(rotation=90)
plt.title('Procedure Descriptions for Newborns Who Stay 120 Days or Longer')
plt.show()

# %%
ccs = df['ccs_diagnosis_description'].value_counts(ascending=False)

# %%
sns.countplot(y ='ccs_diagnosis_description', data= df, palette='cool_r',
             order=sns.set(font_scale=1.2)
sns.set_style("white")
f, ax = plt.subplots(figsize=(8, 9))
sns.barplot(y="CCS Diagnosis Description", x="Length of Stay", data=diag_stay_df[0:5], palette='Set1')
#plt.xticks(rotation=45)
plt.title('Top 5 Diagnoses with Longest Average Length of Stay')
plt.show().index)
plt.ylabel('Location Description of Crimes', fontsize= 20)
plt.title('Top 20 Crime Location In Chicago: 2001 - 2022', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Top 20 Crime Location In Chicago: 2001 - 2022')

# %%
sty = df[['ccs_diagnosis_description','length_of_stay']].groupby('ccs_diagnosis_description', as_index=False).mean()
sty = sty.sort_values(by='length_of_stay', ascending=False, ignore_index=True)
sty
# Out:
#                              ccs_diagnosis_description  length_of_stay
# 0    Short gestation; low birth weight; and fetal g...       30.528536
# 1                        Respiratory distress syndrome       26.903382
# 2                                         Tuberculosis       22.329317
# 3                                            Leukemias       18.969221
# 4          Schizophrenia and other psychotic disorders       16.653243
# ..                                                 ...             ...
# 254                      Acute and chronic tonsillitis        1.812732
# 255                  Prolapse of female genital organs        1.635280
# 256          Hemolytic jaundice and perinatal jaundice        1.564665
# 257                     Medical examination/evaluation        1.389610
# 258           Contraceptive and procreative management        1.250000
#
# [259 rows x 2 columns]

# %%
sns.set(font_scale=1.2)
sns.set_style("white")
f, ax = plt.subplots(figsize=(8, 9))
sns.barplot(y="ccs_diagnosis_description",x='length_of_stay', data=sty[0:10])
#plt.xticks(rotation=45)
plt.title('Top 5 Diagnoses with Longest Average Length of Stay')
plt.show()

# %%
length_of_stay
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-8c90881a7067> in <module>
#       1 f, ax = plt.subplots(figsize=(11, 9))
# ----> 2 sns.boxplot(x="Age Group", y="Length of Stay", data=df)
#       3 ax.set(ylim=(0, 30))
#       4 plt.title('Length of Stay vs. Age Group')
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Age Group'
