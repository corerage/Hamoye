# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/HP/Documents/workspace/Ml-opzoomcamp/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8f83279d75e5> in <module>
# ----> 1 my_tuppy[2] = 6
#       2
#       3
#       4
#       5
#
# TypeError: 'tuple' object does not support item assignment

# %%
plt.figure(figsize=(15,10))  
sns.heatmap(df.corr(),annot=True,linewidths=.5, cmap="Blues")
plt.title('Heatmap showing correlations between numerical data')
plt.show()

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
round(df['Y2017'].mean(), 2)
# Out:
# 140.92

# %%
df.groupby(['Element']).count()
# Out:
#                                         Area Code  Area  Item Code  Item  \
# Element
# Domestic supply quantity                     5295  5295       5295  5295
# Export Quantity                              4403  4403       4403  4403
# Fat supply quantity (g/capita/day)           5023  5023       5023  5023
# Feed                                         1319  1319       1319  1319
# Food                                         4941  4941       4941  4941
# Food supply (kcal/capita/day)                5014  5014       5014  5014
# Food supply quantity (kg/capita/yr)          4905  4905       4905  4905
# Import Quantity                              5139  5139       5139  5139
# Losses                                       2009  2009       2009  2009
# Other uses (non-food)                        1732  1732       1732  1732
# Processing                                   2010  2010       2010  2010
# Production                                   3881  3881       3881  3881
# ...

# %%
df.groupby(['Element']).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# 292836.00

# %%
col=['Area','Y2017']

# %%
new=df[col].reset_index(drop=True)
new
# Out:
#            Area     Y2017
# 0       Algeria  41389.00
# 1       Algeria      0.00
# 2       Algeria   3341.00
# 3       Algeria     92.82
# 4       Algeria     80.19
# ...         ...       ...
# 60938  Zimbabwe     19.00
# 60939  Zimbabwe      1.33
# 60940  Zimbabwe      1.00
# 60941  Zimbabwe      0.04
# 60942  Zimbabwe      0.02
#
# [60943 rows x 2 columns]

# %%
new.groupby(['Area']).sum().sort_values('Area', ascending=True)
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %% [markdown]
# Nigeria

# %%
y= [(2,4), (7,8), (1,5,9)]

# %%
y[1][1]
# Out:
# 8

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
round(df.isnull().sum()*100/len(df), 3)
# Out:
# Area Code       0.000
# Area            0.000
# Item Code       0.000
# Item            0.000
# Element Code    0.000
# Element         0.000
# Unit            0.000
# Y2014           2.607
# Y2015           2.540
# Y2016           2.519
# Y2017           2.471
# Y2018           2.356
# dtype: float64

# %%
col=['Element','Area','Y2015']

# %%
new=df[col]
new
# Out:
#                                       Element      Area     Y2015
# 0               Total Population - Both sexes   Algeria  39728.00
# 1                    Domestic supply quantity   Algeria      0.00
# 2               Food supply (kcal/capita/day)   Algeria   3379.00
# 3      Protein supply quantity (g/capita/day)   Algeria     94.35
# 4          Fat supply quantity (g/capita/day)   Algeria     79.36
# ...                                       ...       ...       ...
# 60938                                    Food  Zimbabwe     46.00
# 60939     Food supply quantity (kg/capita/yr)  Zimbabwe      3.33
# 60940           Food supply (kcal/capita/day)  Zimbabwe      4.00
# 60941  Protein supply quantity (g/capita/day)  Zimbabwe      0.11
# 60942      Fat supply quantity (g/capita/day)  Zimbabwe      0.05
#
# [60943 rows x 3 columns]

# %%
new1=new[new['Area']=='Madagascar']
new1
# Out:
#                                       Element        Area     Y2015
# 30715           Total Population - Both sexes  Madagascar  24234.00
# 30716                Domestic supply quantity  Madagascar      0.00
# 30717           Food supply (kcal/capita/day)  Madagascar   1922.00
# 30718  Protein supply quantity (g/capita/day)  Madagascar     43.26
# 30719      Fat supply quantity (g/capita/day)  Madagascar     22.97
# ...                                       ...         ...       ...
# 32149                                    Food  Madagascar     11.00
# 32150     Food supply quantity (kg/capita/yr)  Madagascar      0.44
# 32151           Food supply (kcal/capita/day)  Madagascar      0.00
# 32152  Protein supply quantity (g/capita/day)  Madagascar      0.01
# 32153      Fat supply quantity (g/capita/day)  Madagascar      0.01
#
# [1439 rows x 3 columns]

# %%
new1.groupby(['Element']).sum()
# Out:
#                                            Y2015
# Element
# Domestic supply quantity                31214.98
# Export Quantity                           494.75
# Fat supply quantity (g/capita/day)         91.85
# Feed                                     2070.22
# Food                                    21120.65
# Food supply (kcal/capita/day)            7685.00
# Food supply quantity (kg/capita/yr)       871.59
# Import Quantity                          1721.80
# Losses                                   2176.00
# Other uses (non-food)                    3957.12
# Processing                               1803.00
# Production                              29482.89
# Protein supply quantity (g/capita/day)    173.05
# Residuals                                -616.00
# Seed                                      699.00
# Stock Variation                          -505.00
# Total Population - Both sexes           24234.00

# %% [markdown]
# 173.05

# %% [markdown]
# set

# %%
s= [['him', 'sell'],[90,28,43]]

# %%
s[0][1][1]
# Out:
# 'e'

# %%
s[0][1]
# Out:
# 'sell'

# %%
df.shape
# Out:
# (60943, 12)
